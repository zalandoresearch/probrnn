# %% [markdown]
# import modules and get command-line parameters if running as script

# %%
from probrnn import models, data, inference
import numpy as np
import json 
from matplotlib import pyplot as plt
from IPython.display import clear_output

# %% [markdown]
# parameters for the model and training

# %%
params = \
    {
        "N_ITERATIONS": 10 ** 5,
        "VALIDATE_EACH": 100,
        "SAVE_EACH": 1000,
        "LOG_EVERY": 50,
        "LEARNING_RATE": 0.0001,
        "N_HIDDEN": 256,
        "N_BINS": 50,
        "BATCH_SIZE": 50,
    }

save_name = "../models/toy_nade_bivariate"
modeltype = models.NADE

# %% [markdown]
# Get some Mackey-Glass model data, which evolves according to:
#
# $$\frac{dx}{dt} = \frac{\beta \, x_{t - \tau}}{1 + (x_{t - \tau})^n} - \gamma \, x_t$$
#
# We take random initial conditions

# %%
datastruct = data.CoupledToyData(n_bins=params["N_BINS"])

x, _ = datastruct._gen(1).next()
x = datastruct.get_readable(x)

plt.figure()
plt.plot(x)
plt.show()

# %% [markdown]
# do some training

# %%
model = modeltype(datastruct, params=params)

training = models.Training(
                            model, 
                            save_name, 
                            save_name + "_training.json",
                          )

def print_function(trer, i, batch):
    if i % 10 == 0:
        clear_output()
        print "loss: {}; iteration {}".format(np.mean(trer[-100:]), i)

training.train(print_function)

# %% [markdown]
# visualize the training errors

# %%
with open(save_name + "_training.json") as f:
    errs = json.load(f)

plt.figure()
plt.plot(np.array(errs["training_error"])[:, 0], 
         np.array(errs["training_error"])[:, 1])
plt.plot(np.array(errs["validation_error"])[:, 0], 
         np.array(errs["validation_error"])[:, 1], 'r')
plt.legend(["training", "validation"])
plt.show()

# %% [markdown]
# plot some weight traces

# %%
for x in errs.keys():
    if x != "training_error" and x != "validation_error" and "train" not in x:
        plt.figure()
        for key in errs[x].keys():
            if key == "mean":
                plt.plot(errs[x][key], 'b', linewidth=5.0)
            elif key == "random":
                plt.plot(errs[x][key], 'c')
            else:
                plt.plot(errs[x][key], 'b', linestyle='--')

        plt.title("variable: {}".format(x))
plt.show()

# %% [markdown]
# load trained model

# %%
load_name = save_name + "_12000"
model = modeltype(datastruct, fn=load_name)
print json.dumps(model.params, indent=4)
# Out:
# restoring...
# INFO:tensorflow:Restoring parameters from ../models/toy_nade_bivariate_12000.ckpt
# {
#     "N_BINS": 50,
#     "LEARNING_RATE": 0.0001,
#     "BATCH_SIZE": 50,
#     "SAVE_EACH": 1000,
#     "N_ITERATIONS": 1000000,
#     "VALIDATE_EACH": 100,
#     "LOG_EVERY": 50,
#     "N_HIDDEN": 256
# }

# %% [markdown]
# try some sampling

# %%
x = model.sample(200)

plt.plot(x[::2])
plt.plot(x[1::2])
plt.show()

# %% [markdown]
# try some imputation

# %%
x = datastruct.simulate()

x_missing = np.zeros(x.shape[0] * 2)
x_missing[::2] = x[:, 0]

x_missing[np.random.choice(len(x), replace=False, size=125)] = np.nan

estimate = inference.NaiveSIS(model, x_missing, 1000, binned=False, quiet=False).estimate()

plt.figure()
plt.plot(x)
plt.plot(x_missing, 'bx')
plt.plot(estimate)
plt.show()
